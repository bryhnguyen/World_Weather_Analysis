# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
        # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description":description })
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 1 | ambovombe
# Processing Record 3 of Set 1 | basco
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | arman
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | la orilla
# Processing Record 12 of Set 1 | magadi
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | geraldton
# Processing Record 15 of Set 1 | jardim
# Processing Record 16 of Set 1 | salinopolis
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | leningradskiy
# Processing Record 23 of Set 1 | vestmannaeyjar
# Processing Record 24 of Set 1 | constitucion
# Processing Record 25 of Set 1 | cururupu
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | mercedes
# Processing Record 28 of Set 1 | nemuro
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | havre
# Processing Record 31 of Set 1 | flinders
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | san lawrenz
# Processing Record 35 of Set 1 | kavaratti
# Processing Record 36 of Set 1 | kedrovyy
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | manavalakurichi
# Processing Record 40 of Set 1 | tapes
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | englehart
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | arandis
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | karratha
# Processing Record 2 of Set 2 | sur
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | kopyevo
# City not found. Skipping...
# Processing Record 6 of Set 2 | aitape
# Processing Record 7 of Set 2 | maba
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | bengkalis
# City not found. Skipping...
# Processing Record 10 of Set 2 | taksimo
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | fortuna
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | nacala
# Processing Record 17 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 2 | phangnga
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 21 of Set 2 | novyy urengoy
# Processing Record 22 of Set 2 | samarai
# Processing Record 23 of Set 2 | imbituba
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | plettenberg bay
# Processing Record 26 of Set 2 | tukrah
# Processing Record 27 of Set 2 | sasovo
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | atar
# Processing Record 30 of Set 2 | matara
# Processing Record 31 of Set 2 | high level
# Processing Record 32 of Set 2 | tikapur
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | tessalit
# Processing Record 35 of Set 2 | vardo
# Processing Record 36 of Set 2 | lorengau
# Processing Record 37 of Set 2 | mosetse
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | bilma
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | sarosd
# Processing Record 42 of Set 2 | acapulco
# Processing Record 43 of Set 2 | hovd
# Processing Record 44 of Set 2 | dunedin
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | campbell river
# Processing Record 47 of Set 2 | poum
# Processing Record 48 of Set 2 | pinega
# Processing Record 49 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 2 | aykhal
# Processing Record 1 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | tucupita
# Processing Record 6 of Set 3 | grand gaube
# Processing Record 7 of Set 3 | vestbygda
# City not found. Skipping...
# Processing Record 8 of Set 3 | pevek
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | grindavik
# Processing Record 11 of Set 3 | oktyabrskoye
# Processing Record 12 of Set 3 | juba
# Processing Record 13 of Set 3 | ushuaia
# Processing Record 14 of Set 3 | bairiki
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | dingle
# Processing Record 17 of Set 3 | kyabram
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | west plains
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | bahia blanca
# Processing Record 22 of Set 3 | haines junction
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | kamenka
# Processing Record 26 of Set 3 | asau
# Processing Record 27 of Set 3 | xingyi
# Processing Record 28 of Set 3 | basti
# Processing Record 29 of Set 3 | wuxi
# Processing Record 30 of Set 3 | sawtell
# Processing Record 31 of Set 3 | richards bay
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | mantua
# Processing Record 34 of Set 3 | songjianghe
# Processing Record 35 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 3 | ponta do sol
# Processing Record 37 of Set 3 | port augusta
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | westport
# Processing Record 40 of Set 3 | guelengdeng
# City not found. Skipping...
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | komsomolskiy
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | tautira
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | severo-yeniseyskiy
# Processing Record 49 of Set 3 | khatanga
# Processing Record 50 of Set 3 | faanui
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | bundaberg
# Processing Record 3 of Set 4 | oloron-sainte-marie
# Processing Record 4 of Set 4 | turukhansk
# Processing Record 5 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 4 | angoche
# Processing Record 7 of Set 4 | oakdale
# Processing Record 8 of Set 4 | port macquarie
# Processing Record 9 of Set 4 | lata
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | vestmanna
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | coari
# Processing Record 14 of Set 4 | koidu
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | margate
# Processing Record 17 of Set 4 | preobrazheniye
# Processing Record 18 of Set 4 | praia da vitoria
# Processing Record 19 of Set 4 | seminole
# Processing Record 20 of Set 4 | cabo san lucas
# Processing Record 21 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 4 | bastrop
# Processing Record 23 of Set 4 | lebu
# Processing Record 24 of Set 4 | bambanglipuro
# Processing Record 25 of Set 4 | paamiut
# Processing Record 26 of Set 4 | sinnamary
# Processing Record 27 of Set 4 | kesennuma
# City not found. Skipping...
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | havoysund
# Processing Record 30 of Set 4 | kitimat
# Processing Record 31 of Set 4 | vao
# Processing Record 32 of Set 4 | vila velha
# Processing Record 33 of Set 4 | hithadhoo
# Processing Record 34 of Set 4 | bougouni
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | kavieng
# Processing Record 37 of Set 4 | tocopilla
# Processing Record 38 of Set 4 | yumen
# Processing Record 39 of Set 4 | te anau
# Processing Record 40 of Set 4 | bose
# Processing Record 41 of Set 4 | flin flon
# Processing Record 42 of Set 4 | ucluelet
# Processing Record 43 of Set 4 | san carlos de bariloche
# Processing Record 44 of Set 4 | agua branca
# Processing Record 45 of Set 4 | puerto ayora
# Processing Record 46 of Set 4 | marzuq
# Processing Record 47 of Set 4 | daru
# Processing Record 48 of Set 4 | umm lajj
# Processing Record 49 of Set 4 | caravelas
# Processing Record 50 of Set 4 | hofn
# Processing Record 1 of Set 5 | bluff
# Processing Record 2 of Set 5 | nanortalik
# Processing Record 3 of Set 5 | natchitoches
# Processing Record 4 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | port hedland
# Processing Record 7 of Set 5 | bereda
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | turinsk
# Processing Record 10 of Set 5 | thunder bay
# Processing Record 11 of Set 5 | anyang
# Processing Record 12 of Set 5 | harper
# Processing Record 13 of Set 5 | safaqis
# City not found. Skipping...
# Processing Record 14 of Set 5 | codrington
# Processing Record 15 of Set 5 | abu samrah
# Processing Record 16 of Set 5 | rocha
# Processing Record 17 of Set 5 | tuktoyaktuk
# Processing Record 18 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 5 | klaksvik
# Processing Record 20 of Set 5 | warragul
# Processing Record 21 of Set 5 | hilo
# Processing Record 22 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | bandarbeyla
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | bantacan
# Processing Record 27 of Set 5 | port hardy
# Processing Record 28 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 5 | antalaha
# Processing Record 30 of Set 5 | mumford
# Processing Record 31 of Set 5 | high prairie
# Processing Record 32 of Set 5 | powell
# Processing Record 33 of Set 5 | east london
# Processing Record 34 of Set 5 | lere
# Processing Record 35 of Set 5 | viedma
# Processing Record 36 of Set 5 | mehamn
# Processing Record 37 of Set 5 | mount isa
# Processing Record 38 of Set 5 | lubyany
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | zapolyarnyy
# Processing Record 41 of Set 5 | son tay
# Processing Record 42 of Set 5 | la baule-escoublac
# Processing Record 43 of Set 5 | libreville
# Processing Record 44 of Set 5 | barcelos
# Processing Record 45 of Set 5 | zabol
# Processing Record 46 of Set 5 | isangel
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | karatau
# Processing Record 49 of Set 5 | teacapan
# Processing Record 50 of Set 5 | tilichiki
# Processing Record 1 of Set 6 | losinyy
# Processing Record 2 of Set 6 | sola
# Processing Record 3 of Set 6 | panjab
# Processing Record 4 of Set 6 | hengshui
# Processing Record 5 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 6 | kasongo-lunda
# Processing Record 7 of Set 6 | lockhart
# Processing Record 8 of Set 6 | antonina
# Processing Record 9 of Set 6 | konin
# Processing Record 10 of Set 6 | mayo
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | dzaoudzi
# Processing Record 13 of Set 6 | luderitz
# Processing Record 14 of Set 6 | morondava
# Processing Record 15 of Set 6 | honningsvag
# Processing Record 16 of Set 6 | moerai
# Processing Record 17 of Set 6 | mackay
# Processing Record 18 of Set 6 | malakal
# Processing Record 19 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 6 | cuiaba
# Processing Record 21 of Set 6 | alizai
# Processing Record 22 of Set 6 | kirakira
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | abha
# Processing Record 25 of Set 6 | maragogi
# Processing Record 26 of Set 6 | bethel
# Processing Record 27 of Set 6 | semey
# Processing Record 28 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 6 | loandjili
# Processing Record 30 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 6 | cherskiy
# Processing Record 32 of Set 6 | hay river
# Processing Record 33 of Set 6 | comodoro rivadavia
# Processing Record 34 of Set 6 | pullman
# Processing Record 35 of Set 6 | mahibadhoo
# Processing Record 36 of Set 6 | krasnogvardeyskiy
# Processing Record 37 of Set 6 | kaseda
# Processing Record 38 of Set 6 | letterkenny
# Processing Record 39 of Set 6 | say
# Processing Record 40 of Set 6 | ouranopolis
# City not found. Skipping...
# Processing Record 41 of Set 6 | kudahuvadhoo
# Processing Record 42 of Set 6 | husavik
# Processing Record 43 of Set 6 | tiznit
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | kamalapuram
# Processing Record 46 of Set 6 | poso
# Processing Record 47 of Set 6 | ixtapa
# Processing Record 48 of Set 6 | vaasa
# Processing Record 49 of Set 6 | berlevag
# Processing Record 50 of Set 6 | intipuca
# Processing Record 1 of Set 7 | luau
# Processing Record 2 of Set 7 | arica
# Processing Record 3 of Set 7 | batagay-alyta
# Processing Record 4 of Set 7 | svetlyy
# Processing Record 5 of Set 7 | alcudia
# Processing Record 6 of Set 7 | tecoanapa
# Processing Record 7 of Set 7 | georgiyevka
# Processing Record 8 of Set 7 | nyurba
# Processing Record 9 of Set 7 | cidreira
# Processing Record 10 of Set 7 | nhulunbuy
# Processing Record 11 of Set 7 | tambura
# Processing Record 12 of Set 7 | khagrachari
# City not found. Skipping...
# Processing Record 13 of Set 7 | iranshahr
# Processing Record 14 of Set 7 | port lincoln
# Processing Record 15 of Set 7 | dzidzantun
# Processing Record 16 of Set 7 | meadow lake
# Processing Record 17 of Set 7 | pascagoula
# Processing Record 18 of Set 7 | goderich
# Processing Record 19 of Set 7 | luena
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | bolshaya irba
# City not found. Skipping...
# Processing Record 22 of Set 7 | zurrieq
# Processing Record 23 of Set 7 | mlowo
# Processing Record 24 of Set 7 | orapa
# Processing Record 25 of Set 7 | kwinana
# Processing Record 26 of Set 7 | kokopo
# Processing Record 27 of Set 7 | kapan
# Processing Record 28 of Set 7 | lavrentiya
# Processing Record 29 of Set 7 | hailar
# Processing Record 30 of Set 7 | padang
# Processing Record 31 of Set 7 | rodrigues alves
# Processing Record 32 of Set 7 | stornoway
# Processing Record 33 of Set 7 | rabo de peixe
# Processing Record 34 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 35 of Set 7 | biak
# Processing Record 36 of Set 7 | faya
# Processing Record 37 of Set 7 | wakkanai
# Processing Record 38 of Set 7 | ossora
# Processing Record 39 of Set 7 | vila franca do campo
# Processing Record 40 of Set 7 | belmonte
# Processing Record 41 of Set 7 | teya
# Processing Record 42 of Set 7 | vanavara
# Processing Record 43 of Set 7 | igarka
# Processing Record 44 of Set 7 | hami
# Processing Record 45 of Set 7 | punta alta
# Processing Record 46 of Set 7 | san lorenzo
# Processing Record 47 of Set 7 | ayagoz
# Processing Record 48 of Set 7 | anchorage
# Processing Record 49 of Set 7 | bonao
# Processing Record 50 of Set 7 | bull savanna
# Processing Record 1 of Set 8 | ancud
# Processing Record 2 of Set 8 | srednekolymsk
# Processing Record 3 of Set 8 | champoton
# Processing Record 4 of Set 8 | teahupoo
# Processing Record 5 of Set 8 | priyutnoye
# Processing Record 6 of Set 8 | sao jose da coroa grande
# Processing Record 7 of Set 8 | toila
# Processing Record 8 of Set 8 | jawala mukhi
# Processing Record 9 of Set 8 | pouebo
# Processing Record 10 of Set 8 | sabha
# Processing Record 11 of Set 8 | houma
# Processing Record 12 of Set 8 | barth
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | saint-marc
# Processing Record 15 of Set 8 | makokou
# Processing Record 16 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 17 of Set 8 | yulara
# Processing Record 18 of Set 8 | raudeberg
# Processing Record 19 of Set 8 | cangucu
# Processing Record 20 of Set 8 | alice springs
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | sibolga
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | rawson
# Processing Record 25 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 8 | salalah
# Processing Record 27 of Set 8 | kvareli
# Processing Record 28 of Set 8 | whitehorse
# Processing Record 29 of Set 8 | cacequi
# Processing Record 30 of Set 8 | ballina
# Processing Record 31 of Set 8 | broome
# Processing Record 32 of Set 8 | gazanjyk
# Processing Record 33 of Set 8 | chapais
# Processing Record 34 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 8 | tuatapere
# Processing Record 36 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 37 of Set 8 | saint anthony
# Processing Record 38 of Set 8 | banting
# Processing Record 39 of Set 8 | ames
# Processing Record 40 of Set 8 | agadez
# Processing Record 41 of Set 8 | buala
# Processing Record 42 of Set 8 | elko
# Processing Record 43 of Set 8 | san patricio
# Processing Record 44 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 8 | jalu
# Processing Record 46 of Set 8 | gogrial
# Processing Record 47 of Set 8 | vila do maio
# Processing Record 48 of Set 8 | camacha
# Processing Record 49 of Set 8 | cuajinicuilapa
# Processing Record 50 of Set 8 | miraflores
# Processing Record 1 of Set 9 | katrineholm
# Processing Record 2 of Set 9 | bitung
# Processing Record 3 of Set 9 | sioux lookout
# Processing Record 4 of Set 9 | sabang
# Processing Record 5 of Set 9 | kysyl-syr
# Processing Record 6 of Set 9 | morant bay
# Processing Record 7 of Set 9 | san andres
# Processing Record 8 of Set 9 | kamaishi
# Processing Record 9 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 9 | santa rosa del sur
# Processing Record 11 of Set 9 | nantucket
# Processing Record 12 of Set 9 | ponta delgada
# Processing Record 13 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 9 | kangundo
# Processing Record 15 of Set 9 | olafsvik
# Processing Record 16 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | saint-louis
# Processing Record 18 of Set 9 | pitea
# Processing Record 19 of Set 9 | paita
# Processing Record 20 of Set 9 | san jose
# Processing Record 21 of Set 9 | kloulklubed
# Processing Record 22 of Set 9 | adre
# Processing Record 23 of Set 9 | merrill
# Processing Record 24 of Set 9 | riyadh
# Processing Record 25 of Set 9 | sitka
# Processing Record 26 of Set 9 | mazagao
# Processing Record 27 of Set 9 | khudumelapye
# Processing Record 28 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 29 of Set 9 | greeneville
# Processing Record 30 of Set 9 | guerrero negro
# Processing Record 31 of Set 9 | chino valley
# Processing Record 32 of Set 9 | hostotipaquillo
# Processing Record 33 of Set 9 | canguaretama
# Processing Record 34 of Set 9 | akdepe
# Processing Record 35 of Set 9 | lavumisa
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | jhelum
# Processing Record 38 of Set 9 | alirajpur
# Processing Record 39 of Set 9 | sistranda
# Processing Record 40 of Set 9 | gushi
# Processing Record 41 of Set 9 | washington
# Processing Record 42 of Set 9 | namatanai
# Processing Record 43 of Set 9 | kanniyakumari
# Processing Record 44 of Set 9 | nouadhibou
# Processing Record 45 of Set 9 | taoudenni
# Processing Record 46 of Set 9 | voh
# Processing Record 47 of Set 9 | denpasar
# Processing Record 48 of Set 9 | kaitangata
# Processing Record 49 of Set 9 | spetsai
# City not found. Skipping...
# Processing Record 50 of Set 9 | garissa
# Processing Record 1 of Set 10 | pangnirtung
# Processing Record 2 of Set 10 | price
# Processing Record 3 of Set 10 | contai
# Processing Record 4 of Set 10 | oranjemund
# Processing Record 5 of Set 10 | gat
# Processing Record 6 of Set 10 | half moon bay
# Processing Record 7 of Set 10 | meulaboh
# Processing Record 8 of Set 10 | mandera
# Processing Record 9 of Set 10 | makinsk
# Processing Record 10 of Set 10 | maniitsoq
# Processing Record 11 of Set 10 | necochea
# Processing Record 12 of Set 10 | catamarca
# Processing Record 13 of Set 10 | acaponeta
# Processing Record 14 of Set 10 | taburbah
# City not found. Skipping...
# Processing Record 15 of Set 10 | pahalgam
# Processing Record 16 of Set 10 | salinas
# Processing Record 17 of Set 10 | tommot
# Processing Record 18 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 10 | adrar
# Processing Record 20 of Set 10 | taltal
# Processing Record 21 of Set 10 | gravdal
# Processing Record 22 of Set 10 | tezu
# Processing Record 23 of Set 10 | kruisfontein
# Processing Record 24 of Set 10 | radhanpur
# Processing Record 25 of Set 10 | lagos
# Processing Record 26 of Set 10 | pontes e lacerda
# Processing Record 27 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 10 | santarem
# Processing Record 29 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 30 of Set 10 | galesong
# Processing Record 31 of Set 10 | vaitape
# Processing Record 32 of Set 10 | baghdad
# Processing Record 33 of Set 10 | bandar
# Processing Record 34 of Set 10 | alamo
# Processing Record 35 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 10 | krasnyy kut
# Processing Record 37 of Set 10 | vrangel
# Processing Record 38 of Set 10 | harlingen
# Processing Record 39 of Set 10 | pochutla
# Processing Record 40 of Set 10 | peleduy
# Processing Record 41 of Set 10 | saint-augustin
# Processing Record 42 of Set 10 | port keats
# Processing Record 43 of Set 10 | hamilton
# Processing Record 44 of Set 10 | maningrida
# Processing Record 45 of Set 10 | bernburg
# Processing Record 46 of Set 10 | trairi
# Processing Record 47 of Set 10 | benghazi
# Processing Record 48 of Set 10 | ribeira brava
# Processing Record 49 of Set 10 | hambantota
# Processing Record 50 of Set 10 | bonthe
# Processing Record 1 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 11 | bonoua
# Processing Record 3 of Set 11 | emerald
# Processing Record 4 of Set 11 | sudova vyshnya
# Processing Record 5 of Set 11 | muros
# Processing Record 6 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 11 | provideniya
# Processing Record 8 of Set 11 | butembo
# Processing Record 9 of Set 11 | lompoc
# Processing Record 10 of Set 11 | barcelona
# Processing Record 11 of Set 11 | saint-joseph
# Processing Record 12 of Set 11 | saquena
# Processing Record 13 of Set 11 | esik
# Processing Record 14 of Set 11 | qasigiannguit
# Processing Record 15 of Set 11 | peniche
# Processing Record 16 of Set 11 | ritchie
# Processing Record 17 of Set 11 | tias
# Processing Record 18 of Set 11 | agarak
# Processing Record 19 of Set 11 | bartica
# Processing Record 20 of Set 11 | luanda
# Processing Record 21 of Set 11 | addis zemen
# City not found. Skipping...
# Processing Record 22 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 11 | kiama
# Processing Record 24 of Set 11 | sale
# Processing Record 25 of Set 11 | yakeshi
# Processing Record 26 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 27 of Set 11 | civita castellana
# Processing Record 28 of Set 11 | marsaxlokk
# Processing Record 29 of Set 11 | krasnoselkup
# Processing Record 30 of Set 11 | ouadda
# Processing Record 31 of Set 11 | neiafu
# Processing Record 32 of Set 11 | shieli
# Processing Record 33 of Set 11 | tolmezzo
# Processing Record 34 of Set 11 | atambua
# Processing Record 35 of Set 11 | altay
# Processing Record 36 of Set 11 | port blair
# Processing Record 37 of Set 11 | iqaluit
# Processing Record 38 of Set 11 | tumbes
# Processing Record 39 of Set 11 | nanae
# Processing Record 40 of Set 11 | red bluff
# Processing Record 41 of Set 11 | oxelosund
# Processing Record 42 of Set 11 | plaeng yao
# Processing Record 43 of Set 11 | saulkrasti
# Processing Record 44 of Set 11 | nouakchott
# Processing Record 45 of Set 11 | vilyuysk
# Processing Record 46 of Set 11 | marawi
# Processing Record 47 of Set 11 | kizilskoye
# Processing Record 48 of Set 11 | santa maria
# Processing Record 49 of Set 11 | oyama
# Processing Record 50 of Set 11 | tharrawaddy
# City not found. Skipping...
# Processing Record 1 of Set 12 | knysna
# Processing Record 2 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 12 | monaragala
# Processing Record 4 of Set 12 | mezen
# Processing Record 5 of Set 12 | darnah
# Processing Record 6 of Set 12 | vanderhoof
# Processing Record 7 of Set 12 | erenhot
# Processing Record 8 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 12 | waipawa
# Processing Record 10 of Set 12 | burnie
# Processing Record 11 of Set 12 | zhezkazgan
# Processing Record 12 of Set 12 | balabac
# Processing Record 13 of Set 12 | shestakovo
# Processing Record 14 of Set 12 | nehe
# Processing Record 15 of Set 12 | pustoshka
# Processing Record 16 of Set 12 | saint-pierre
# Processing Record 17 of Set 12 | bambari
# Processing Record 18 of Set 12 | yicheng
# Processing Record 19 of Set 12 | portland
# Processing Record 20 of Set 12 | semme
# Processing Record 21 of Set 12 | tura
# Processing Record 22 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 23 of Set 12 | wattegama
# Processing Record 24 of Set 12 | eskil
# Processing Record 25 of Set 12 | beloha
# Processing Record 26 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 12 | tshikapa
# Processing Record 28 of Set 12 | kiomboi
# Processing Record 29 of Set 12 | olavarria
# Processing Record 30 of Set 12 | la rioja
# Processing Record 31 of Set 12 | pombia
# Processing Record 32 of Set 12 | nkwerre
# Processing Record 33 of Set 12 | pulaski
# Processing Record 34 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 35 of Set 12 | teguldet
# Processing Record 36 of Set 12 | amot
# Processing Record 37 of Set 12 | santo domingo
# Processing Record 38 of Set 12 | wegorzewo
# Processing Record 39 of Set 12 | rize
# Processing Record 40 of Set 12 | seoul
# Processing Record 41 of Set 12 | aklavik
# Processing Record 42 of Set 12 | banda aceh
# Processing Record 43 of Set 12 | bonfim
# Processing Record 44 of Set 12 | mitsamiouli
# Processing Record 45 of Set 12 | gornyak
# Processing Record 46 of Set 12 | natal
# Processing Record 47 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 12 | buraydah
# Processing Record 49 of Set 12 | dumas
# Processing Record 50 of Set 12 | dorchester
# Processing Record 1 of Set 13 | kiunga
# Processing Record 2 of Set 13 | camabatela
# Processing Record 3 of Set 13 | rundu
# Processing Record 4 of Set 13 | ust-tarka
# Processing Record 5 of Set 13 | puerto narino
# Processing Record 6 of Set 13 | kimbe
# Processing Record 7 of Set 13 | deputatskiy
# Processing Record 8 of Set 13 | sao joao da barra
# Processing Record 9 of Set 13 | ambon
# Processing Record 10 of Set 13 | lincoln
# Processing Record 11 of Set 13 | kungurtug
# Processing Record 12 of Set 13 | bathsheba
# Processing Record 13 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 14 of Set 13 | polyarnyy
# Processing Record 15 of Set 13 | copiapo
# Processing Record 16 of Set 13 | marsh harbour
# Processing Record 17 of Set 13 | pataskala
# Processing Record 18 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 13 | bonavista
# Processing Record 20 of Set 13 | narsaq
# Processing Record 21 of Set 13 | anadyr
# Processing Record 22 of Set 13 | wenling
# Processing Record 23 of Set 13 | mukhen
# Processing Record 24 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 13 | ambilobe
# Processing Record 26 of Set 13 | kindu
# Processing Record 27 of Set 13 | jinchang
# Processing Record 28 of Set 13 | asuncion
# Processing Record 29 of Set 13 | nuuk
# Processing Record 30 of Set 13 | poronaysk
# Processing Record 31 of Set 13 | axim
# Processing Record 32 of Set 13 | kendari
# Processing Record 33 of Set 13 | betafo
# Processing Record 34 of Set 13 | fort nelson
# Processing Record 35 of Set 13 | yar-sale
# Processing Record 36 of Set 13 | puri
# Processing Record 37 of Set 13 | starkville
# Processing Record 38 of Set 13 | canchungo
# Processing Record 39 of Set 13 | merauke
# Processing Record 40 of Set 13 | valparaiso
# Processing Record 41 of Set 13 | beaverlodge
# Processing Record 42 of Set 13 | polje
# Processing Record 43 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 13 | sal rei
# Processing Record 45 of Set 13 | tual
# Processing Record 46 of Set 13 | birao
# Processing Record 47 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 13 | prince rupert
# Processing Record 49 of Set 13 | rumonge
# Processing Record 50 of Set 13 | foumban
# Processing Record 1 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 14 | white rock
# Processing Record 3 of Set 14 | kangaatsiaq
# Processing Record 4 of Set 14 | srandakan
# Processing Record 5 of Set 14 | yarmouth
# Processing Record 6 of Set 14 | jacareacanga
# Processing Record 7 of Set 14 | tiarei
# Processing Record 8 of Set 14 | estelle
# Processing Record 9 of Set 14 | sisimiut
# Processing Record 10 of Set 14 | ayan
# Processing Record 11 of Set 14 | nieuw amsterdam
# Processing Record 12 of Set 14 | zhigansk
# Processing Record 13 of Set 14 | mancio lima
# Processing Record 14 of Set 14 | gerash
# Processing Record 15 of Set 14 | palmer
# Processing Record 16 of Set 14 | ahipara
# Processing Record 17 of Set 14 | itarema
# Processing Record 18 of Set 14 | bubaque
# Processing Record 19 of Set 14 | temir
# Processing Record 20 of Set 14 | vana-voidu
# City not found. Skipping...
# Processing Record 21 of Set 14 | young
# Processing Record 22 of Set 14 | penzance
# Processing Record 23 of Set 14 | jiaocheng
# Processing Record 24 of Set 14 | cuamba
# Processing Record 25 of Set 14 | hvolsvollur
# Processing Record 26 of Set 14 | sharjah
# Processing Record 27 of Set 14 | bongaree
# Processing Record 28 of Set 14 | ust-nera
# Processing Record 29 of Set 14 | ercis
# Processing Record 30 of Set 14 | neuquen
# Processing Record 31 of Set 14 | znamenskoye
# Processing Record 32 of Set 14 | shimoda
# Processing Record 33 of Set 14 | ouesso
# Processing Record 34 of Set 14 | marion
# Processing Record 35 of Set 14 | kulhudhuffushi
# Processing Record 36 of Set 14 | verona
# Processing Record 37 of Set 14 | masumbwe
# Processing Record 38 of Set 14 | cockburn town
# Processing Record 39 of Set 14 | sovetskiy
# Processing Record 40 of Set 14 | kibre mengist
# Processing Record 41 of Set 14 | kharhial
# Processing Record 42 of Set 14 | tir pol
# City not found. Skipping...
# Processing Record 43 of Set 14 | carlsbad
# Processing Record 44 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 45 of Set 14 | porto de moz
# Processing Record 46 of Set 14 | guayama
# Processing Record 47 of Set 14 | calabozo
# Processing Record 48 of Set 14 | moron
# Processing Record 49 of Set 14 | chumikan
# Processing Record 50 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 15 | shingu
# Processing Record 2 of Set 15 | grand island
# Processing Record 3 of Set 15 | bradley
# Processing Record 4 of Set 15 | eyl
# Processing Record 5 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 15 | jalingo
# Processing Record 7 of Set 15 | warwick
# Processing Record 8 of Set 15 | wewak
# Processing Record 9 of Set 15 | newcastle
# Processing Record 10 of Set 15 | nizwa
# Processing Record 11 of Set 15 | tuy hoa
# Processing Record 12 of Set 15 | nyzhni sirohozy
# Processing Record 13 of Set 15 | adjumani
# Processing Record 14 of Set 15 | mogadishu
# Processing Record 15 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 15 | sorland
# Processing Record 17 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 15 | mineiros
# Processing Record 19 of Set 15 | karpuninskiy
# City not found. Skipping...
# Processing Record 20 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 15 | syava
# Processing Record 22 of Set 15 | nattam
# Processing Record 23 of Set 15 | voykove
# Processing Record 24 of Set 15 | alexandria
# Processing Record 25 of Set 15 | gigmoto
# Processing Record 26 of Set 15 | mackenzie
# Processing Record 27 of Set 15 | wanning
# Processing Record 28 of Set 15 | calama
# Processing Record 29 of Set 15 | krasne
# Processing Record 30 of Set 15 | barabinsk
# Processing Record 31 of Set 15 | mayumba
# Processing Record 32 of Set 15 | nabire
# Processing Record 33 of Set 15 | coahuayana
# Processing Record 34 of Set 15 | labytnangi
# Processing Record 35 of Set 15 | wamba
# Processing Record 36 of Set 15 | verkh-usugli
# Processing Record 37 of Set 15 | mahina
# Processing Record 38 of Set 15 | salym
# Processing Record 39 of Set 15 | silver city
# Processing Record 40 of Set 15 | kuching
# Processing Record 41 of Set 15 | namtsy
# Processing Record 42 of Set 15 | khani
# Processing Record 43 of Set 15 | vangaindrano
# Processing Record 44 of Set 15 | capinopolis
# Processing Record 45 of Set 15 | manaus
# Processing Record 46 of Set 15 | cap malheureux
# Processing Record 47 of Set 15 | aberdeen
# Processing Record 48 of Set 15 | hun
# Processing Record 49 of Set 15 | praya
# Processing Record 50 of Set 15 | verkhoyansk
# Processing Record 1 of Set 16 | omboue
# Processing Record 2 of Set 16 | las palmas
# Processing Record 3 of Set 16 | naze
# Processing Record 4 of Set 16 | kagadi
# Processing Record 5 of Set 16 | ulaanbaatar
# Processing Record 6 of Set 16 | acandi
# Processing Record 7 of Set 16 | firovo
# Processing Record 8 of Set 16 | ati
# Processing Record 9 of Set 16 | lazaro cardenas
# Processing Record 10 of Set 16 | murray bridge
# Processing Record 11 of Set 16 | kennewick
# Processing Record 12 of Set 16 | mae sai
# Processing Record 13 of Set 16 | manbij
# Processing Record 14 of Set 16 | ahuimanu
# Processing Record 15 of Set 16 | ola
# Processing Record 16 of Set 16 | san felipe
# Processing Record 17 of Set 16 | inhambane
# Processing Record 18 of Set 16 | vitimskiy
# City not found. Skipping...
# Processing Record 19 of Set 16 | oktyabrskiy
# Processing Record 20 of Set 16 | bowen
# Processing Record 21 of Set 16 | minab
# Processing Record 22 of Set 16 | ierapetra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ambovombe -25.1667   46.0833     76.77        63           2
# 1         Basco  20.4487  121.9702     70.59        72          99
# 2     Carnarvon -24.8667  113.6333     87.87        58          23
# 3         Arman  59.7000  150.1667      7.59        78         100
# 4       Mataura -46.1927  168.8643     73.87        57          92
# 5       Rikitea -23.1203 -134.9692     77.38        64         100
# 6  Punta Arenas -53.1500  -70.9167     48.31        71          40
# 7          Chuy -33.6971  -53.4616     68.32        89           0
# 8        Castro -24.7911  -50.0119     62.53        99         100
# 9     La Orilla  17.9833 -102.2333     72.66        75           0
#
#    Wind Speed Country                 Date Current Description
# 0        9.13      MG  2022-01-31 04:50:25           clear sky
# 1       27.58      PH  2022-01-31 04:50:26     overcast clouds
# 2       24.16      AU  2022-01-31 04:48:45          few clouds
# 3       16.89      RU  2022-01-31 04:50:26     overcast clouds
# 4        4.94      NZ  2022-01-31 04:46:42     overcast clouds
# 5        5.79      PF  2022-01-31 04:46:46     overcast clouds
# 6       19.57      CL  2022-01-31 04:42:43    scattered clouds
# 7        8.57      UY  2022-01-31 04:46:47           clear sky
# 8        5.82      BR  2022-01-31 04:50:27     overcast clouds
# 9        4.54      MX  2022-01-31 04:50:27           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
